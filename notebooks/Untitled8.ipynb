# %%
import pandas as pd
import numpy as np

datadf = pd.read_csv('data/ranked_number_of_patches.csv')
datadf
# len(datadf['distractorc
# Out:
#     Unnamed: 0        target  q_rank  number_of_patches_min  \
# 0            0       gestalt       0                      1
# 1            1       gestalt       1                   1554
# 2            2       gestalt       2                   3260
# 3            3       gestalt       3                  11768
# 4            4       gestalt       4                  18065
# 5            5       gestalt       5                  31334
# 6            6       gestalt       6                  95448
# 7            7       gestalt       7                 100869
# 8            8       gestalt       8                 106706
# 9            9       gestalt       9                 177501
# 10          10  less gestalt       0                      1
# 11          11  less gestalt       1                   1554
# 12          12  less gestalt       2                   3260
# 13          13  less gestalt       3                  11768
# 14          14  less gestalt       4                  18065
# 15          15  less gestalt       5                  31334
# 16          16  less gestalt       6                  95448
# 17          17  less gestalt       7                 100869
# 18          18  less gestalt       8                 106706
# 19          19  less gestalt       9                 177501
# 20          20     no target       0                      1
# 21          21     no target       1                   1554
# 22          22     no target       2                   3260
# 23          23     no target       3                  11768
# 24          24     no target       4                  18065
# 25          25     no target       5                  31334
# 26          26     no target       6                  95448
# 27          27     no target       7                 100869
# 28          28     no target       8                 106706
# 29          29     no target       9                 177501
#
#     number_of_patches_max  timetaken_mean  correct_mean  \
# 0                    1190     1285.139445      0.937829
# 1                    3044     1300.178935      0.931295
# 2                   11697     1329.580913      0.935873
# 3                   16878     1358.059536      0.934926
# 4                   28308     1268.199836      0.950860
# 5                   95164     1656.508679      0.852830
# 6                  100482     1523.246956      0.912481
# 7                  104733     1512.791976      0.925334
# 8                  177456     1502.787771      0.937433
# 9                  194392     1447.576685      0.949153
# 10                   1190     1453.023050      0.817518
# 11                   3044     1476.559615      0.868846
# 12                  11697     1545.720735      0.867636
# 13                  16878     1522.221787      0.853685
# 14                  28308     1341.013912      0.940262
# 15                  95164     1944.789696      0.728885
# 16                 100482     1701.494447      0.853696
# 17                 104733     1703.815301      0.854714
# 18                 177456     1640.085915      0.892254
# 19                 194392     1498.204928      0.949076
# 20                   1190     1631.709332      0.978577
# 21                   3044     1711.016481      0.971445
# 22                  11697     1758.940000      0.979429
# 23                  16878     1737.677459      0.975541
# 24                  28308     1572.017916      0.976524
# 25                  95164     2084.038737      0.966031
# 26                 100482     1875.200076      0.971959
# 27                 104733     1885.883469      0.975897
# 28                 177456     1893.390878      0.974523
# 29                 194392     1673.548931      0.983347
#
#                                     distractorcatlist
# 0   ['random-red-all-none', 'random-blue-all-none'...
# 1   ['random-blue-high-none', 'random-red-high-non...
# 2   ['random-red-medium-none', 'random-mixed-mediu...
# 3   ['clustered-matches-small rough-dark', 'cluste...
# 4   ['random-blue-high-dark', 'no distractor-missi...
# 5   ['random-mixed-high-dark', 'random-mixed-high-...
# 6   ['random-matches-high-streets', 'clustered-blu...
# 7   ['random-red-high-streets', 'random-blue-high-...
# 8   ['random-red-low-streets', 'random-red-high-im...
# 9   ['random-red-medium-imagery', 'random-blue-low...
# 10  ['random-matches-all-none', 'clustered-matches...
# 11  ['random-matches-high-none', 'random-blue-high...
# 12  ['random-blue-medium-none', 'random-red-medium...
# 13  ['clustered-matches-medium rough-dark', 'clust...
# 14  ['random-blue-high-dark', 'random-matches-high...
# 15  ['random-mixed-high-none', 'random-mixed-high-...
# 16  ['random-matches-high-streets', 'clustered-blu...
# 17  ['random-red-high-streets', 'random-blue-high-...
# 18  ['random-mixed-medium-streets', 'random-matche...
# 19  ['random-red-medium-imagery', 'random-red-low-...
# 20  ['random-matches-all-none', 'random-blue-all-n...
# 21  ['random-blue-high-none', 'random-matches-high...
# 22  ['random-blue-medium-none', 'random-matches-me...
# 23  ['clustered-blue-large rough-dark', 'clustered...
# 24  ['random-red-medium-dark', 'random-blue-low-da...
# 25  ['random-mixed-high-none', 'random-mixed-high-...
# 26  ['random-matches-high-streets', 'random-matche...
# 27  ['random-blue-high-streets', 'random-red-high-...
# 28  ['random-matches-medium-streets', 'random-mixe...
# 29  ['random-blue-medium-imagery', 'random-red-med...

# %%
datadf['distractorcatlist'] = datadf['distractorcatlist'].str.split(', ', expand=True).stack().unique().tolist()
datadf['distractorcatlist']
# datadf['distractorcatlistlent'] = datadf['distractorcatlist'].str.replace('[','', regex=False).replace(']','', regex=False).replace('\'','', regex=False).replace(', ',',', regex=False).str.split(",")

# datadf['distractorcatlistlent'].reset_index()['distractorcatlistlent'].unique()

# # print( type(datadf['distractorcatlistlent'].astype(str).unique() ))

# datadf['distractorcatlistlent'].apply(sorted).transform(tuple).unique()

# datadf['distractorcatlistlent'] = datadf['distractorcatlist'].unique()
# print(datadf['distractorcatlistlent'].unique())
# datadf.distractorcatlistlent.unique()

# datadf['distractorcatlistlenLENGTH'] = datadf['distractorcatlistlent'].str.len()
# datadf['distractorcatlistlenLENGTH']

# datadf['distractorcatlistlenLENGTH'] = datadf['distractorcatlistlent'].str.len()
# datadf['distractorcatlistlent']

# datadf.to_csv('data/test---.csv')

# datadf['distractorcatlistlent'] = datadf['distractorcatlistlent']
# Tarray = datadf['distractorcatlist'].apply(np.array)
# list1 = Tarray.tolist()
# joined_string = ",".join(list1)

# datadf['test'] = joined_string
# datadf['test']
# # # Using for loop
# # for i in list1:
# #     print(i)

# # datadf['distractorcatlist'] = np.unique(datadf['distractorcatlist'].apply(np.array))
# # len(datadf['distractorcatlist'].apply(np.array))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-6bab09fd0f72> in <module>
# ----> 1 datadf['distractorcatlist'] = datadf['distractorcatlist'].str.split(', ', expand=True).stack().unique().tolist()
#       2 datadf['distractorcatlist']
#       3 # datadf['distractorcatlistlent'] = datadf['distractorcatlist'].str.replace('[','', regex=False).replace(']','', regex=False).replace('\'','', regex=False).replace(', ',',', regex=False).str.split(",")
#       4
#       5 # datadf['distractorcatlistlent'].reset_index()['distractorcatlistlent'].unique()
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3237         """
#    3238         self._ensure_valid_index(value)
# -> 3239         value = self._sanitize_column(key, value)
#    3240         NDFrame._set_item(self, key, value)
#    3241
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3894
#    3895             # turn me into an ndarray
# -> 3896             value = sanitize_index(value, self.index)
#    3897             if not isinstance(value, (np.ndarray, Index)):
#    3898                 if isinstance(value, list) and len(value) > 0:
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     749     """
#     750     if len(data) != len(index):
# --> 751         raise ValueError(
#     752             "Length of values "
#     753             f"({len(data)}) "
#
# ValueError: Length of values (176) does not match length of index (30)
